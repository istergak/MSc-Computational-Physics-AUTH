# %% [markdown]
# **MSc Computational Physics AUTh**<br>
# **Academic Year: 2024-2025**<br>
# **Master's Thesis**<br>
#
# **Thesis Title:**<br>
# # **"Reconstruction of the EoSs of Exotic Stars using ML and ANNs regression models"**
#
# **Implemented by: Ioannis Stergakis**<br>
# **AEM: 4439**<br>
#
# **Jupyter Notebook: JN5**<br>
# **Name: "Assessing_summary_ml_reg.ipynb"**<br>
#
# **Description:**<br>
# **Assessing machine learning regression models**<br>
# **1. Summarizing and saving the results of metrics in .csv files**
# **2. Printing and comparing their metrics**<br>
# **3. Making groups of bar plots to compare test vs overfitting results for various types of X data**<br>
# **4. Displaying learning curves of the machine learning models**
#
#
# **Abbrevations:**<br>
# **1. NS -> Neutron Star**<br>
# **2. QS -> Quark Star**<br>
# **3. ML -> Machine Learning**

# %%
# Importing useful modules
from data_analysis_ES_ML import *
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # 1. Neutron Stars

# %% [markdown]
# ## **1.1 Summarizing and saving results in files**

# %% [markdown]
# ### **A. Storaging metric results in .csv files**

# %%
# Saving MSLE results
assess_ML(star_type="NS",mag_reg="dpde",x_data_types=["16X","16X_rwsh","32X","32X_rwsh"]).save_metric_results("msle") # results for Slope dP/dE prediction
assess_ML(star_type="NS",mag_reg="enrg",x_data_types=["16X","16X_rwsh","32X","32X_rwsh"]).save_metric_results("msle") # results for Slope E_c (energy on center) prediction
assess_ML(star_type="NS",mag_reg="gamma",x_data_types=["16X","16X_rwsh","32X","32X_rwsh"]).save_metric_results("msle") # results for polytropic parameter Γ prediction
assess_ML(star_type="NS",mag_reg="PcMmax",x_data_types=["16X","16X_rwsh","32X","32X_rwsh"]).save_metric_results("msle") # results for PcMmax (center pressure at maximum mass) prediction
# Out:
# The MSLE results for "dpde" prediction have been summarized and saved on the NS_dpde_msle_res.csv file !!!
# The MSLE results for "enrg" prediction have been summarized and saved on the NS_enrg_msle_res.csv file !!!
# The MSLE results for "gamma" prediction have been summarized and saved on the NS_gamma_msle_res.csv file !!!
# The MSLE results for "PcMmax" prediction have been summarized and saved on the NS_PcMmax_msle_res.csv file !!!

# %%
# Saving MSE results
assess_ML(star_type="NS",mag_reg="dpde",x_data_types=["16X","16X_rwsh","32X","32X_rwsh"]).save_metric_results("mse") # results for Slope dP/dE prediction
assess_ML(star_type="NS",mag_reg="enrg",x_data_types=["16X","16X_rwsh","32X","32X_rwsh"]).save_metric_results("mse") # results for Slope E_c (energy on center) prediction
assess_ML(star_type="NS",mag_reg="gamma",x_data_types=["16X","16X_rwsh","32X","32X_rwsh"]).save_metric_results("mse") # results for polytropic parameter Γ prediction
assess_ML(star_type="NS",mag_reg="PcMmax",x_data_types=["16X","16X_rwsh","32X","32X_rwsh"]).save_metric_results("mse") # results for PcMmax (center pressure at maximum mass) prediction
# Out:
# The MSE results for "dpde" prediction have been summarized and saved on the NS_dpde_mse_res.csv file !!!
# The MSE results for "enrg" prediction have been summarized and saved on the NS_enrg_mse_res.csv file !!!
# The MSE results for "gamma" prediction have been summarized and saved on the NS_gamma_mse_res.csv file !!!
# The MSE results for "PcMmax" prediction have been summarized and saved on the NS_PcMmax_mse_res.csv file !!!

# %% [markdown]
# ### **B. Storaging learning curves info in .pkl files**

# %%
# Learning curves for predicting slope dP/dE = c_s^2 values
assess_ML("NS","dpde",["16X","16X_rwsh","32X","32X_rwsh"]).save_lc_info(0) # using 16X explanatory data
assess_ML("NS","dpde",["16X","16X_rwsh","32X","32X_rwsh"]).save_lc_info(1) # using 16X rowwise shuffled explanatory data
assess_ML("NS","dpde",["16X","16X_rwsh","32X","32X_rwsh"]).save_lc_info(2) # using 32X explanatory data
assess_ML("NS","dpde",["16X","16X_rwsh","32X","32X_rwsh"]).save_lc_info(3) # using 32X rowwise shuffled explanatory data
# Out:
# The learning curves info for "16X" X data and "dpde" Y data have been summarized and saved on the NS_lc_dpde_16X.pkl file !!!
# The learning curves info for "16X_rwsh" X data and "dpde" Y data have been summarized and saved on the NS_lc_dpde_16X_rwsh.pkl file !!!
# The learning curves info for "32X" X data and "dpde" Y data have been summarized and saved on the NS_lc_dpde_32X.pkl file !!!
# The learning curves info for "32X_rwsh" X data and "dpde" Y data have been summarized and saved on the NS_lc_dpde_32X_rwsh.pkl file !!!

# %%
# Learning curves for predicting energy on center E_c values
assess_ML("NS","enrg",["16X","16X_rwsh","32X","32X_rwsh"]).save_lc_info(0) # using 16X explanatory data
assess_ML("NS","enrg",["16X","16X_rwsh","32X","32X_rwsh"]).save_lc_info(1) # using 16X rowwise shuffled explanatory data
assess_ML("NS","enrg",["16X","16X_rwsh","32X","32X_rwsh"]).save_lc_info(2) # using 32X explanatory data
assess_ML("NS","enrg",["16X","16X_rwsh","32X","32X_rwsh"]).save_lc_info(3) # using 32X rowwise shuffled explanatory data
# Out:
# The learning curves info for "16X" X data and "enrg" Y data have been summarized and saved on the NS_lc_enrg_16X.pkl file !!!
# The learning curves info for "16X_rwsh" X data and "enrg" Y data have been summarized and saved on the NS_lc_enrg_16X_rwsh.pkl file !!!
# The learning curves info for "32X" X data and "enrg" Y data have been summarized and saved on the NS_lc_enrg_32X.pkl file !!!
# The learning curves info for "32X_rwsh" X data and "enrg" Y data have been summarized and saved on the NS_lc_enrg_32X_rwsh.pkl file !!!

# %%
# Learning curves for predicting polytropic parameter Γ values
assess_ML("NS","gamma",["16X","16X_rwsh","32X","32X_rwsh"]).save_lc_info(0) # using 16X explanatory data
assess_ML("NS","gamma",["16X","16X_rwsh","32X","32X_rwsh"]).save_lc_info(1) # using 16X rowwise shuffled explanatory data
assess_ML("NS","gamma",["16X","16X_rwsh","32X","32X_rwsh"]).save_lc_info(2) # using 32X explanatory data
assess_ML("NS","gamma",["16X","16X_rwsh","32X","32X_rwsh"]).save_lc_info(3) # using 32X rowwise shuffled explanatory data
# Out:
# The learning curves info for "16X" X data and "gamma" Y data have been summarized and saved on the NS_lc_gamma_16X.pkl file !!!
# The learning curves info for "16X_rwsh" X data and "gamma" Y data have been summarized and saved on the NS_lc_gamma_16X_rwsh.pkl file !!!
# The learning curves info for "32X" X data and "gamma" Y data have been summarized and saved on the NS_lc_gamma_32X.pkl file !!!
# The learning curves info for "32X_rwsh" X data and "gamma" Y data have been summarized and saved on the NS_lc_gamma_32X_rwsh.pkl file !!!

# %%
# Learning curves for predicting center pressure at maximum mass P_c(Mmax) values
assess_ML("NS","PcMmax",["16X","16X_rwsh","32X","32X_rwsh"]).save_lc_info(0) # using 16X explanatory data
assess_ML("NS","PcMmax",["16X","16X_rwsh","32X","32X_rwsh"]).save_lc_info(1) # using 16X rowwise shuffled explanatory data
assess_ML("NS","PcMmax",["16X","16X_rwsh","32X","32X_rwsh"]).save_lc_info(2) # using 32X explanatory data
assess_ML("NS","PcMmax",["16X","16X_rwsh","32X","32X_rwsh"]).save_lc_info(3) # using 32X rowwise shuffled explanatory data
# Out:
# The learning curves info for "16X" X data and "PcMmax" Y data have been summarized and saved on the NS_lc_PcMmax_16X.pkl file !!!
# The learning curves info for "16X_rwsh" X data and "PcMmax" Y data have been summarized and saved on the NS_lc_PcMmax_16X_rwsh.pkl file !!!
# The learning curves info for "32X" X data and "PcMmax" Y data have been summarized and saved on the NS_lc_PcMmax_32X.pkl file !!!
# The learning curves info for "32X_rwsh" X data and "PcMmax" Y data have been summarized and saved on the NS_lc_PcMmax_32X_rwsh.pkl file !!!

# %% [markdown]
# ## **1.2 Printing the metric results in PrettyTable format**

# %% [markdown]
# ### **A. Predicting slope $\frac{dP}{dE}$ values**

# %%
# MSLE results
print(">Slope dP/dE prediction (MSLE results):")
assess_ML(star_type="NS",mag_reg="dpde",x_data_types=["16X","16X_rwsh","32X","32X_rwsh"]).print_metric_results("msle")
# MSE results
print("\n>Slope dP/dE prediction (MSE results):")
assess_ML(star_type="NS",mag_reg="dpde",x_data_types=["16X","16X_rwsh","32X","32X_rwsh"]).print_metric_results("mse")
# Out:
# >Slope dP/dE prediction (MSLE results):
# +------------------+-------------------------+-------------------------+-------------------------+-------------------------+
# |  models\X_type   |        16X (ovf.)       |     16X_rwsh (ovf.)     |        32X (ovf.)       |     32X_rwsh (ovf.)     |
# +------------------+-------------------------+-------------------------+-------------------------+-------------------------+
# |   DecisionTree   | 3.0235e-03 (2.0476e-03) | 4.9993e-03 (4.2553e-03) | 2.8262e-03 (1.8766e-03) | 5.5351e-03 (4.7641e-03) |
# |   RandomForest   | 2.1430e-03 (1.4128e-03) | 3.4415e-03 (2.3538e-03) | 1.7799e-03 (1.1429e-03) | 3.8669e-03 (2.5501e-03) |
# | GradientBoosting | 2.3090e-03 (1.9800e-03) | 3.9921e-03 (3.6130e-03) | 1.9953e-03 (1.7091e-03) | 4.0659e-03 (3.6482e-03) |
# |     AdaBoost     | 3.7374e-03 (3.6265e-03) | 6.2259e-03 (6.1033e-03) | 3.6120e-03 (3.5242e-03) | 6.2785e-03 (6.1256e-03) |
# ...

# %% [markdown]
# ### **B. Predicting energy on center $E_c$ values**

# %%
# MSLE results
print(">Energy on center E_c prediction (MSLE results):")
assess_ML(star_type="NS",mag_reg="enrg",x_data_types=["16X","16X_rwsh","32X","32X_rwsh"]).print_metric_results("msle")
# MSE results
print("\n>Energy on center E_c prediction (MSE results):")
assess_ML(star_type="NS",mag_reg="enrg",x_data_types=["16X","16X_rwsh","32X","32X_rwsh"]).print_metric_results("mse")
# Out:
# >Energy on center E_c prediction (MSLE results):
# +------------------+-------------------------+-------------------------+-------------------------+-------------------------+
# |  models\X_type   |        16X (ovf.)       |     16X_rwsh (ovf.)     |        32X (ovf.)       |     32X_rwsh (ovf.)     |
# +------------------+-------------------------+-------------------------+-------------------------+-------------------------+
# |   DecisionTree   | 6.8356e-03 (2.5899e-03) | 1.2273e-02 (6.1780e-03) | 6.2076e-03 (2.2343e-03) | 1.4480e-02 (6.6756e-03) |
# |   RandomForest   | 4.3119e-03 (3.2175e-03) | 7.0381e-03 (5.0759e-03) | 3.4691e-03 (2.3859e-03) | 7.5623e-03 (5.2305e-03) |
# | GradientBoosting | 3.4607e-03 (2.9196e-03) | 6.8144e-03 (5.8392e-03) | 2.6281e-03 (2.1638e-03) | 6.8475e-03 (5.7457e-03) |
# |     AdaBoost     | 7.5351e-03 (7.3400e-03) | 1.9748e-02 (1.9189e-02) | 6.9362e-03 (6.6866e-03) | 1.9773e-02 (1.8983e-02) |
# ...

# %% [markdown]
# ### **C. Predicting polytropic parameter $Γ$ values**

# %%
# MSLE results
print(">Polytropic parameter Γ prediction (MSLE results):")
assess_ML(star_type="NS",mag_reg="gamma",x_data_types=["16X","16X_rwsh","32X","32X_rwsh"]).print_metric_results("msle")
# MSE results
print("\n>Polytropic parameter Γ prediction (MSE results):")
assess_ML(star_type="NS",mag_reg="gamma",x_data_types=["16X","16X_rwsh","32X","32X_rwsh"]).print_metric_results("mse")
# Out:
# >Polytropic parameter Γ prediction (MSLE results):
# +------------------+-------------------------+-------------------------+-------------------------+-------------------------+
# |  models\X_type   |        16X (ovf.)       |     16X_rwsh (ovf.)     |        32X (ovf.)       |     32X_rwsh (ovf.)     |
# +------------------+-------------------------+-------------------------+-------------------------+-------------------------+
# |   DecisionTree   | 4.4432e-02 (3.2231e-02) | 7.0594e-02 (5.9447e-02) | 3.9366e-02 (2.6383e-02) | 7.5573e-02 (7.2814e-02) |
# |   RandomForest   | 3.4187e-02 (2.3465e-02) | 5.2192e-02 (3.8156e-02) | 2.6898e-02 (1.7182e-02) | 5.6697e-02 (3.9641e-02) |
# | GradientBoosting | 3.5299e-02 (3.3151e-02) | 5.4673e-02 (5.2260e-02) | 2.8697e-02 (2.6538e-02) | 5.8003e-02 (5.5046e-02) |
# |     AdaBoost     | 5.0415e-02 (5.1110e-02) | 7.5085e-02 (7.6647e-02) | 4.7348e-02 (4.7947e-02) | 7.5357e-02 (7.6684e-02) |
# ...

# %% [markdown]
# ### **D. Predicting center pressure at maximum mass $P_c(M_{max})$ values**

# %%
# MSLE results
print(">Center pressure at maximum mass P_c(Mmax) prediction (MSLE results):")
assess_ML(star_type="NS",mag_reg="PcMmax",x_data_types=["16X","16X_rwsh","32X","32X_rwsh"]).print_metric_results("msle")
# MSE results
print("\n>Center pressure at maximum mass P_c(Mmax) prediction (MSE results):")
assess_ML(star_type="NS",mag_reg="PcMmax",x_data_types=["16X","16X_rwsh","32X","32X_rwsh"]).print_metric_results("mse")
# Out:
# >Center pressure at maximum mass P_c(Mmax) prediction (MSLE results):
# +------------------+-------------------------+-------------------------+-------------------------+-------------------------+
# |  models\X_type   |        16X (ovf.)       |     16X_rwsh (ovf.)     |        32X (ovf.)       |     32X_rwsh (ovf.)     |
# +------------------+-------------------------+-------------------------+-------------------------+-------------------------+
# |   DecisionTree   | 5.1727e-02 (2.8086e-02) | 1.0921e-01 (8.3716e-02) | 4.8989e-02 (2.4465e-02) | 1.2830e-01 (1.0346e-01) |
# |   RandomForest   | 3.6599e-02 (2.1709e-02) | 7.3853e-02 (4.4168e-02) | 3.0813e-02 (1.7264e-02) | 9.8869e-02 (5.8223e-02) |
# | GradientBoosting | 4.5147e-02 (4.0141e-02) | 9.6605e-02 (9.1556e-02) | 4.3579e-02 (3.7749e-02) | 1.0488e-01 (9.9411e-02) |
# |     AdaBoost     | 8.2859e-02 (8.3357e-02) | 1.2212e-01 (1.2258e-01) | 8.0852e-02 (8.1567e-02) | 1.2931e-01 (1.2919e-01) |
# ...

# %% [markdown]
# ## **1.3 Making groups of bar plots**

# %% [markdown]
# ### **A. Predicting slope $\frac{dP}{dE}$ values**

# %%
# Initialzing the figure and axis
fig_gbar_dpde_NS,axis_gbar_dpde_NS = plt.subplots(2,1,figsize=(10,8))

# Initializing the bar colors
bar_clrs = ["cadetblue","goldenrod","mediumseagreen","salmon"]

# MSLE results
assess_ML(star_type="NS",mag_reg="dpde",x_data_types=["16X","16X_rwsh","32X","32X_rwsh"]).make_bar_plot("msle",axis_gbar_dpde_NS[0],bar_colors=bar_clrs)
# MSE results
assess_ML(star_type="NS",mag_reg="dpde",x_data_types=["16X","16X_rwsh","32X","32X_rwsh"]).make_bar_plot("mse",axis_gbar_dpde_NS[1])

fig_gbar_dpde_NS.tight_layout()

# %% [markdown]
# ### **B. Predicting energy on center $E_c$ values**

# %%
# Initialzing the figure and axis
fig_gbar_enrg_NS,axis_gbar_enrg_NS = plt.subplots(2,1,figsize=(10,8))

# Initializing the bar colors
bar_clrs = ["cadetblue","goldenrod","mediumseagreen","salmon"]

# MSLE results
assess_ML(star_type="NS",mag_reg="enrg",x_data_types=["16X","16X_rwsh","32X","32X_rwsh"]).make_bar_plot("msle",axis_gbar_enrg_NS[0],bar_colors=bar_clrs)
# MSE results
assess_ML(star_type="NS",mag_reg="enrg",x_data_types=["16X","16X_rwsh","32X","32X_rwsh"]).make_bar_plot("mse",axis_gbar_enrg_NS[1])

fig_gbar_enrg_NS.tight_layout()

# %% [markdown]
# ### **C. Predicting polytropic parameter $Γ$ values**

# %%
# Initialzing the figure and axis
fig_gbar_gamma_NS,axis_gbar_gamma_NS = plt.subplots(2,1,figsize=(10,8))

# Initializing the bar colors
bar_clrs = ["cadetblue","goldenrod","mediumseagreen","salmon"]

# MSLE results
assess_ML(star_type="NS",mag_reg="gamma",x_data_types=["16X","16X_rwsh","32X","32X_rwsh"]).make_bar_plot("msle",axis_gbar_gamma_NS[0],bar_colors=bar_clrs)
# MSE results
assess_ML(star_type="NS",mag_reg="gamma",x_data_types=["16X","16X_rwsh","32X","32X_rwsh"]).make_bar_plot("mse",axis_gbar_gamma_NS[1])

fig_gbar_gamma_NS.tight_layout()

# %% [markdown]
# ### **D. Predicting center pressure at maximum mass $P_c(M_{max})$ values**

# %%
# Initialzing the figure and axis
fig_gbar_PcMmax_NS,axis_gbar_PcMmax_NS = plt.subplots(2,1,figsize=(10,8))

# Initializing the bar colors
bar_clrs = ["cadetblue","goldenrod","mediumseagreen","salmon"]

# MSLE results
assess_ML(star_type="NS",mag_reg="PcMmax",x_data_types=["16X","16X_rwsh","32X","32X_rwsh"]).make_bar_plot("msle",axis_gbar_PcMmax_NS[0],bar_colors=bar_clrs)
# MSE results
assess_ML(star_type="NS",mag_reg="PcMmax",x_data_types=["16X","16X_rwsh","32X","32X_rwsh"]).make_bar_plot("mse",axis_gbar_PcMmax_NS[1])

fig_gbar_PcMmax_NS.tight_layout()

# %% [markdown]
# ## **1.4 Displaying learning for various types of X (explanatory) data**

# %% [markdown]
# ### **A. Predicting slope $\frac{dP}{dE}$ values**

# %%
# Using 16X data
fig_lc_dpde_NS_16X,axis_lc_dpde_NS_16X = plt.subplots(1,1,figsize=(11,6))
colors_lc = ["cadetblue","goldenrod","darkgray","salmon"]
assess_ML(star_type="NS",mag_reg="dpde",x_data_types=["16X","16X_rwsh","32X","32X_rwsh"]).plot_learning_curves(0,axis_lc_dpde_NS_16X,colors_lc)
fig_lc_dpde_NS_16X.tight_layout()
fig_lc_dpde_NS_16X.savefig("NS_dpde_16X_lc.pdf",dpi=300)

# %%
# Using 16X rowwise shuffled data
fig_lc_dpde_NS_16X_rwsh,axis_lc_dpde_NS_16X_rwsh = plt.subplots(1,1,figsize=(11,6))
colors_lc = ["cadetblue","goldenrod","darkgray","salmon"]
assess_ML(star_type="NS",mag_reg="dpde",x_data_types=["16X","16X_rwsh","32X","32X_rwsh"]).plot_learning_curves(1,axis_lc_dpde_NS_16X_rwsh,colors_lc)
fig_lc_dpde_NS_16X_rwsh.tight_layout()
fig_lc_dpde_NS_16X_rwsh.savefig("NS_dpde_16X_rwsh_lc.pdf",dpi=300)

# %%
# Using 32X data
fig_lc_dpde_NS_32X,axis_lc_dpde_NS_32X = plt.subplots(1,1,figsize=(11,6))
colors_lc = ["cadetblue","goldenrod","darkgray","salmon"]
assess_ML(star_type="NS",mag_reg="dpde",x_data_types=["16X","16X_rwsh","32X","32X_rwsh"]).plot_learning_curves(2,axis_lc_dpde_NS_32X,colors_lc)
fig_lc_dpde_NS_32X.tight_layout()
fig_lc_dpde_NS_32X.savefig("NS_dpde_32X_lc.pdf",dpi=300)

# %%
# Using 32X rowwise shuffled data
fig_lc_dpde_NS_32X_rwsh,axis_lc_dpde_NS_32X_rwsh = plt.subplots(1,1,figsize=(11,6))
colors_lc = ["cadetblue","goldenrod","darkgray","salmon"]
assess_ML(star_type="NS",mag_reg="dpde",x_data_types=["16X","16X_rwsh","32X","32X_rwsh"]).plot_learning_curves(3,axis_lc_dpde_NS_32X_rwsh,colors_lc)
fig_lc_dpde_NS_32X_rwsh.tight_layout()
fig_lc_dpde_NS_32X_rwsh.savefig("NS_dpde_32X_rwsh_lc.pdf",dpi=300)

# %% [markdown]
# ### **B. Predicting energy on center $E_c$ values**

# %%
# Using 16X data
fig_lc_enrg_NS_16X,axis_lc_enrg_NS_16X = plt.subplots(1,1,figsize=(9,6))
colors_lc = ["cadetblue","goldenrod","darkgray","salmon"]
assess_ML(star_type="NS",mag_reg="enrg",x_data_types=["16X","16X_rwsh","32X","32X_rwsh"]).plot_learning_curves(0,axis_lc_enrg_NS_16X,colors_lc)

# %%
# Using 16X rowwise shuffled data
fig_lc_enrg_NS_16X_rwsh,axis_lc_enrg_NS_16X_rwsh = plt.subplots(1,1,figsize=(9,6))
colors_lc = ["cadetblue","goldenrod","darkgray","salmon"]
assess_ML(star_type="NS",mag_reg="enrg",x_data_types=["16X","16X_rwsh","32X","32X_rwsh"]).plot_learning_curves(1,axis_lc_enrg_NS_16X_rwsh,colors_lc)

# %%
# Using 32X data
fig_lc_enrg_NS_32X,axis_lc_enrg_NS_32X = plt.subplots(1,1,figsize=(9,6))
colors_lc = ["cadetblue","goldenrod","darkgray","salmon"]
assess_ML(star_type="NS",mag_reg="enrg",x_data_types=["16X","16X_rwsh","32X","32X_rwsh"]).plot_learning_curves(2,axis_lc_enrg_NS_32X,colors_lc)

# %%
# Using 32X rowwise shuffled data
fig_lc_enrg_NS_32X_rwsh,axis_lc_enrg_NS_32X_rwsh = plt.subplots(1,1,figsize=(9,6))
colors_lc = ["cadetblue","goldenrod","darkgray","salmon"]
assess_ML(star_type="NS",mag_reg="enrg",x_data_types=["16X","16X_rwsh","32X","32X_rwsh"]).plot_learning_curves(3,axis_lc_enrg_NS_32X_rwsh,colors_lc)

# %% [markdown]
# ### **C. Predicting polytropic parameter $Γ$ values**

# %%
# Using 16X data
fig_lc_gamma_NS_16X,axis_lc_gamma_NS_16X = plt.subplots(1,1,figsize=(9,6))
colors_lc = ["cadetblue","goldenrod","darkgray","salmon"]
assess_ML(star_type="NS",mag_reg="gamma",x_data_types=["16X","16X_rwsh","32X","32X_rwsh"]).plot_learning_curves(0,axis_lc_gamma_NS_16X,colors_lc)

# %%
# Using 16X rowwise shuffled data
fig_lc_gamma_NS_16X_rwsh,axis_lc_gamma_NS_16X_rwsh = plt.subplots(1,1,figsize=(9,6))
colors_lc = ["cadetblue","goldenrod","darkgray","salmon"]
assess_ML(star_type="NS",mag_reg="gamma",x_data_types=["16X","16X_rwsh","32X","32X_rwsh"]).plot_learning_curves(1,axis_lc_gamma_NS_16X_rwsh,colors_lc)

# %%
# Using 32X data
fig_lc_gamma_NS_32X,axis_lc_gamma_NS_32X = plt.subplots(1,1,figsize=(9,6))
colors_lc = ["cadetblue","goldenrod","darkgray","salmon"]
assess_ML(star_type="NS",mag_reg="gamma",x_data_types=["16X","16X_rwsh","32X","32X_rwsh"]).plot_learning_curves(2,axis_lc_gamma_NS_32X,colors_lc)

# %%
# Using 32X rowwise shuffled data
fig_lc_gamma_NS_32X_rwsh,axis_lc_gamma_NS_32X_rwsh = plt.subplots(1,1,figsize=(9,6))
colors_lc = ["cadetblue","goldenrod","darkgray","salmon"]
assess_ML(star_type="NS",mag_reg="gamma",x_data_types=["16X","16X_rwsh","32X","32X_rwsh"]).plot_learning_curves(3,axis_lc_gamma_NS_32X_rwsh,colors_lc)

# %% [markdown]
# ### **D. Predicting center pressure at maximum mass $P_c(M_{max})$ values**

# %%
# Using 16X data
fig_lc_PcMmax_NS_16X,axis_lc_PcMmax_NS_16X = plt.subplots(1,1,figsize=(9,6))
colors_lc = ["cadetblue","goldenrod","darkgray","salmon"]
assess_ML(star_type="NS",mag_reg="PcMmax",x_data_types=["16X","16X_rwsh","32X","32X_rwsh"]).plot_learning_curves(0,axis_lc_PcMmax_NS_16X,colors_lc)

# %%
# Using 16X rowwise shuffled data
fig_lc_PcMmax_NS_16X_rwsh,axis_lc_PcMmax_NS_16X_rwsh = plt.subplots(1,1,figsize=(9,6))
colors_lc = ["cadetblue","goldenrod","darkgray","salmon"]
assess_ML(star_type="NS",mag_reg="PcMmax",x_data_types=["16X","16X_rwsh","32X","32X_rwsh"]).plot_learning_curves(1,axis_lc_PcMmax_NS_16X_rwsh,colors_lc)

# %%
# Using 32X data
fig_lc_PcMmax_NS_32X,axis_lc_PcMmax_NS_32X = plt.subplots(1,1,figsize=(9,6))
colors_lc = ["cadetblue","goldenrod","darkgray","salmon"]
assess_ML(star_type="NS",mag_reg="PcMmax",x_data_types=["16X","16X_rwsh","32X","32X_rwsh"]).plot_learning_curves(2,axis_lc_PcMmax_NS_32X,colors_lc)

# %%
# Using 32X rowwise shuffled data
fig_lc_PcMmax_NS_32X_rwsh,axis_lc_PcMmax_NS_32X_rwsh = plt.subplots(1,1,figsize=(9,6))
colors_lc = ["cadetblue","goldenrod","darkgray","salmon"]
assess_ML(star_type="NS",mag_reg="PcMmax",x_data_types=["16X","16X_rwsh","32X","32X_rwsh"]).plot_learning_curves(3,axis_lc_PcMmax_NS_32X_rwsh,colors_lc)

# %% [markdown]
# # 2. Quark Stars

# %% [markdown]
# ## **2.1 Summarizing and saving metric results in files**

# %% [markdown]
# ### **A. Storaging metric results in .csv files**

# %%
# Saving MSLE results
assess_ML(star_type="QS",mag_reg="dpde",x_data_types=["16X","16X_rwsh","32X","32X_rwsh"]).save_metric_results("msle") # results for Slope dP/dE prediction
assess_ML(star_type="QS",mag_reg="enrg",x_data_types=["16X","16X_rwsh","32X","32X_rwsh"]).save_metric_results("msle") # results for Slope E_c (energy on center) prediction
assess_ML(star_type="QS",mag_reg="PcMmax",x_data_types=["16X","16X_rwsh","32X","32X_rwsh"]).save_metric_results("msle") # results for PcMmax (center pressure at maximum mass) prediction
# Out:
# The MSLE results for "dpde" prediction have been summarized and saved on the QS_dpde_msle_res.csv file !!!
# The MSLE results for "enrg" prediction have been summarized and saved on the QS_enrg_msle_res.csv file !!!
# The MSLE results for "PcMmax" prediction have been summarized and saved on the QS_PcMmax_msle_res.csv file !!!

# %%
# Saving MSE results
assess_ML(star_type="QS",mag_reg="dpde",x_data_types=["16X","16X_rwsh","32X","32X_rwsh"]).save_metric_results("mse") # results for Slope dP/dE prediction
assess_ML(star_type="QS",mag_reg="enrg",x_data_types=["16X","16X_rwsh","32X","32X_rwsh"]).save_metric_results("mse") # results for Slope E_c (energy on center) prediction
assess_ML(star_type="QS",mag_reg="PcMmax",x_data_types=["16X","16X_rwsh","32X","32X_rwsh"]).save_metric_results("mse") # results for PcMmax (center pressure at maximum mass) prediction
# Out:
# The MSE results for "dpde" prediction have been summarized and saved on the QS_dpde_mse_res.csv file !!!
# The MSE results for "enrg" prediction have been summarized and saved on the QS_enrg_mse_res.csv file !!!
# The MSE results for "PcMmax" prediction have been summarized and saved on the QS_PcMmax_mse_res.csv file !!!

# %% [markdown]
# ### **B. Storaging learning curves info in .pkl files**

# %%
# Learning curves for predicting slope dP/dE = c_s^2 values
assess_ML("QS","dpde",["16X","16X_rwsh","32X","32X_rwsh"]).save_lc_info(0) # using 16X explanatory data
assess_ML("QS","dpde",["16X","16X_rwsh","32X","32X_rwsh"]).save_lc_info(1) # using 16X rowwise shuffled explanatory data
assess_ML("QS","dpde",["16X","16X_rwsh","32X","32X_rwsh"]).save_lc_info(2) # using 32X explanatory data
assess_ML("QS","dpde",["16X","16X_rwsh","32X","32X_rwsh"]).save_lc_info(3) # using 32X rowwise shuffled explanatory data
# Out:
# The learning curves info for "16X" X data and "dpde" Y data have been summarized and saved on the QS_lc_dpde_16X.pkl file !!!
# The learning curves info for "16X_rwsh" X data and "dpde" Y data have been summarized and saved on the QS_lc_dpde_16X_rwsh.pkl file !!!
# The learning curves info for "32X" X data and "dpde" Y data have been summarized and saved on the QS_lc_dpde_32X.pkl file !!!
# The learning curves info for "32X_rwsh" X data and "dpde" Y data have been summarized and saved on the QS_lc_dpde_32X_rwsh.pkl file !!!

# %%
# Learning curves for predicting energy on center E_c values
assess_ML("QS","enrg",["16X","16X_rwsh","32X","32X_rwsh"]).save_lc_info(0) # using 16X explanatory data
assess_ML("QS","enrg",["16X","16X_rwsh","32X","32X_rwsh"]).save_lc_info(1) # using 16X rowwise shuffled explanatory data
assess_ML("QS","enrg",["16X","16X_rwsh","32X","32X_rwsh"]).save_lc_info(2) # using 32X explanatory data
assess_ML("QS","enrg",["16X","16X_rwsh","32X","32X_rwsh"]).save_lc_info(3) # using 32X rowwise shuffled explanatory data
# Out:
# The learning curves info for "16X" X data and "enrg" Y data have been summarized and saved on the QS_lc_enrg_16X.pkl file !!!
# The learning curves info for "16X_rwsh" X data and "enrg" Y data have been summarized and saved on the QS_lc_enrg_16X_rwsh.pkl file !!!
# The learning curves info for "32X" X data and "enrg" Y data have been summarized and saved on the QS_lc_enrg_32X.pkl file !!!
# The learning curves info for "32X_rwsh" X data and "enrg" Y data have been summarized and saved on the QS_lc_enrg_32X_rwsh.pkl file !!!

# %%
# Learning curves for predicting center pressure at maximum mass P_c(Mmax) values
assess_ML("QS","PcMmax",["16X","16X_rwsh","32X","32X_rwsh"]).save_lc_info(0) # using 16X explanatory data
assess_ML("QS","PcMmax",["16X","16X_rwsh","32X","32X_rwsh"]).save_lc_info(1) # using 16X rowwise shuffled explanatory data
assess_ML("QS","PcMmax",["16X","16X_rwsh","32X","32X_rwsh"]).save_lc_info(2) # using 32X explanatory data
assess_ML("QS","PcMmax",["16X","16X_rwsh","32X","32X_rwsh"]).save_lc_info(3) # using 32X rowwise shuffled explanatory data
# Out:
# The learning curves info for "16X" X data and "PcMmax" Y data have been summarized and saved on the QS_lc_PcMmax_16X.pkl file !!!
# The learning curves info for "16X_rwsh" X data and "PcMmax" Y data have been summarized and saved on the QS_lc_PcMmax_16X_rwsh.pkl file !!!
# The learning curves info for "32X" X data and "PcMmax" Y data have been summarized and saved on the QS_lc_PcMmax_32X.pkl file !!!
# The learning curves info for "32X_rwsh" X data and "PcMmax" Y data have been summarized and saved on the QS_lc_PcMmax_32X_rwsh.pkl file !!!

# %% [markdown]
# ## **2.2 Printing the metric results in PrettyTable format**

# %% [markdown]
# ### **A. Predicting slope $\frac{dP}{dE}$ values**

# %%
# MSLE results
print(">Slope dP/dE prediction (MSLE results):")
assess_ML(star_type="QS",mag_reg="dpde",x_data_types=["16X","16X_rwsh","32X","32X_rwsh"]).print_metric_results("msle")
# MSE results
print("\n>Slope dP/dE prediction (MSE results):")
assess_ML(star_type="QS",mag_reg="dpde",x_data_types=["16X","16X_rwsh","32X","32X_rwsh"]).print_metric_results("mse")
# Out:
# >Slope dP/dE prediction (MSLE results):
# +------------------+-------------------------+-------------------------+-------------------------+-------------------------+
# |  models\X_type   |        16X (ovf.)       |     16X_rwsh (ovf.)     |        32X (ovf.)       |     32X_rwsh (ovf.)     |
# +------------------+-------------------------+-------------------------+-------------------------+-------------------------+
# |   DecisionTree   | 5.8051e-04 (4.1227e-04) | 8.8290e-04 (7.9914e-04) | 5.7637e-04 (4.0782e-04) | 9.2141e-04 (8.3821e-04) |
# |   RandomForest   | 3.9425e-04 (2.1733e-04) | 6.2994e-04 (3.4841e-04) | 3.1377e-04 (1.5388e-04) | 6.4955e-04 (3.2665e-04) |
# | GradientBoosting | 4.0827e-04 (3.7461e-04) | 7.3642e-04 (6.9028e-04) | 3.2597e-04 (2.9245e-04) | 7.4472e-04 (6.9128e-04) |
# |     AdaBoost     | 7.1226e-04 (7.0117e-04) | 9.0417e-04 (9.0057e-04) | 6.4150e-04 (6.3346e-04) | 9.0372e-04 (8.9804e-04) |
# ...

# %% [markdown]
# ### **B. Predicting energy on center $E_c$ values**

# %%
# MSLE results
print(">Energy on center E_c prediction (MSLE results):")
assess_ML(star_type="QS",mag_reg="enrg",x_data_types=["16X","16X_rwsh","32X","32X_rwsh"]).print_metric_results("msle")
# MSE results
print("\n>Energy on center E_c prediction (MSE results):")
assess_ML(star_type="QS",mag_reg="enrg",x_data_types=["16X","16X_rwsh","32X","32X_rwsh"]).print_metric_results("mse")
# Out:
# >Energy on center E_c prediction (MSLE results):
# +------------------+-------------------------+-------------------------+-------------------------+-------------------------+
# |  models\X_type   |        16X (ovf.)       |     16X_rwsh (ovf.)     |        32X (ovf.)       |     32X_rwsh (ovf.)     |
# +------------------+-------------------------+-------------------------+-------------------------+-------------------------+
# |   DecisionTree   | 3.6095e-03 (2.5676e-03) | 6.5697e-03 (3.3801e-03) | 3.3969e-03 (2.3621e-03) | 7.5953e-03 (4.0274e-03) |
# |   RandomForest   | 2.2061e-03 (1.4800e-03) | 3.8003e-03 (2.3422e-03) | 1.7356e-03 (1.1109e-03) | 3.8041e-03 (2.1615e-03) |
# | GradientBoosting | 2.1772e-03 (1.9927e-03) | 4.0515e-03 (3.7498e-03) | 1.6425e-03 (1.4728e-03) | 3.9313e-03 (3.5872e-03) |
# |     AdaBoost     | 3.6580e-03 (3.6512e-03) | 5.9456e-03 (5.9427e-03) | 3.0939e-03 (3.0910e-03) | 5.7952e-03 (5.7617e-03) |
# ...

# %% [markdown]
# ### **C. Predicting center pressure at maximum mass $P_c(M_{max})$ values**

# %%
# MSLE results
print(">Center pressure at maximum mass P_c(Mmax) prediction (MSLE results):")
assess_ML(star_type="QS",mag_reg="PcMmax",x_data_types=["16X","16X_rwsh","32X","32X_rwsh"]).print_metric_results("msle")
# MSE results
print("\n>Center pressure at maximum mass P_c(Mmax) prediction (MSE results):")
assess_ML(star_type="QS",mag_reg="PcMmax",x_data_types=["16X","16X_rwsh","32X","32X_rwsh"]).print_metric_results("mse")
# Out:
# >Center pressure at maximum mass P_c(Mmax) prediction (MSLE results):
# +------------------+-------------------------+-------------------------+-------------------------+-------------------------+
# |  models\X_type   |        16X (ovf.)       |     16X_rwsh (ovf.)     |        32X (ovf.)       |     32X_rwsh (ovf.)     |
# +------------------+-------------------------+-------------------------+-------------------------+-------------------------+
# |   DecisionTree   | 9.0678e-03 (5.8958e-03) | 1.5901e-02 (1.1417e-02) | 8.7068e-03 (5.1289e-03) | 1.6733e-02 (1.1747e-02) |
# |   RandomForest   | 6.1680e-03 (3.8987e-03) | 1.0385e-02 (5.6837e-03) | 4.5605e-03 (2.2163e-03) | 9.2069e-03 (4.6525e-03) |
# | GradientBoosting | 6.4380e-03 (5.8341e-03) | 1.0310e-02 (9.2770e-03) | 4.7486e-03 (4.2601e-03) | 9.1830e-03 (8.2318e-03) |
# |     AdaBoost     | 1.1542e-02 (1.1347e-02) | 1.6314e-02 (1.6105e-02) | 1.0510e-02 (1.0499e-02) | 1.4833e-02 (1.4684e-02) |
# ...

# %% [markdown]
# ## **2.3 Making groups of bar plots**

# %% [markdown]
# ### **A. Predicting slope $\frac{dP}{dE}$ values**

# %%
# Initialzing the figure and axis
fig_gbar_dpde_QS,axis_gbar_dpde_QS = plt.subplots(2,1,figsize=(10,8))

# Initializing the bar colors
bar_clrs = ["cadetblue","goldenrod","mediumseagreen","salmon"]

# MSLE results
assess_ML(star_type="QS",mag_reg="dpde",x_data_types=["16X","16X_rwsh","32X","32X_rwsh"]).make_bar_plot("msle",axis_gbar_dpde_QS[0],bar_colors=bar_clrs)
# MSE results
assess_ML(star_type="QS",mag_reg="dpde",x_data_types=["16X","16X_rwsh","32X","32X_rwsh"]).make_bar_plot("mse",axis_gbar_dpde_QS[1])

fig_gbar_dpde_QS.tight_layout()

# %% [markdown]
# ### **B. Predicting energy on center $E_c$ values**

# %%
# Initialzing the figure and axis
fig_gbar_enrg_QS,axis_gbar_enrg_QS = plt.subplots(2,1,figsize=(10,8))

# Initializing the bar colors
bar_clrs = ["cadetblue","goldenrod","mediumseagreen","salmon"]

# MSLE results
assess_ML(star_type="QS",mag_reg="enrg",x_data_types=["16X","16X_rwsh","32X","32X_rwsh"]).make_bar_plot("msle",axis_gbar_enrg_QS[0],bar_colors=bar_clrs)
# MSE results
assess_ML(star_type="QS",mag_reg="enrg",x_data_types=["16X","16X_rwsh","32X","32X_rwsh"]).make_bar_plot("mse",axis_gbar_enrg_QS[1])

fig_gbar_enrg_QS.tight_layout()

# %% [markdown]
# ### **C. Predicting center pressure at maximum mass $P_c(M_{max})$ values**

# %%
# Initialzing the figure and axis
fig_gbar_PcMmax_QS,axis_gbar_PcMmax_QS = plt.subplots(2,1,figsize=(10,8))

# Initializing the bar colors
bar_clrs = ["cadetblue","goldenrod","mediumseagreen","salmon"]

# MSLE results
assess_ML(star_type="QS",mag_reg="PcMmax",x_data_types=["16X","16X_rwsh","32X","32X_rwsh"]).make_bar_plot("msle",axis_gbar_PcMmax_QS[0],bar_colors=bar_clrs)
# MSE results
assess_ML(star_type="QS",mag_reg="PcMmax",x_data_types=["16X","16X_rwsh","32X","32X_rwsh"]).make_bar_plot("mse",axis_gbar_PcMmax_QS[1])

fig_gbar_PcMmax_QS.tight_layout()

# %% [markdown]
# ## **2.4 Displaying learning for various types of X (explanatory) data**

# %% [markdown]
# ### **A. Predicting slope $\frac{dP}{dE}$ values**

# %%
# Using 16X data
fig_lc_dpde_QS_16X,axis_lc_dpde_QS_16X = plt.subplots(1,1,figsize=(11,6))
colors_lc = ["cadetblue","goldenrod","darkgray","salmon"]
assess_ML(star_type="QS",mag_reg="dpde",x_data_types=["16X","16X_rwsh","32X","32X_rwsh"]).plot_learning_curves(0,axis_lc_dpde_QS_16X,colors_lc)
fig_lc_dpde_QS_16X.tight_layout()
#fig_lc_dpde_QS_16X.savefig("QS_dpde_16X_lc.pdf",dpi=300)

# %%
# Using 16X rowwise shuffled data
fig_lc_dpde_QS_16X_rwsh,axis_lc_dpde_QS_16X_rwsh = plt.subplots(1,1,figsize=(11,6))
colors_lc = ["cadetblue","goldenrod","darkgray","salmon"]
assess_ML(star_type="QS",mag_reg="dpde",x_data_types=["16X","16X_rwsh","32X","32X_rwsh"]).plot_learning_curves(1,axis_lc_dpde_QS_16X_rwsh,colors_lc)
fig_lc_dpde_QS_16X_rwsh.tight_layout()
#fig_lc_dpde_QS_16X_rwsh.savefig("QS_dpde_16X_rwsh_lc.pdf",dpi=300)

# %%
# Using 32X data
fig_lc_dpde_QS_32X,axis_lc_dpde_QS_32X = plt.subplots(1,1,figsize=(11,6))
colors_lc = ["cadetblue","goldenrod","darkgray","salmon"]
assess_ML(star_type="QS",mag_reg="dpde",x_data_types=["16X","16X_rwsh","32X","32X_rwsh"]).plot_learning_curves(2,axis_lc_dpde_QS_32X,colors_lc)
fig_lc_dpde_QS_32X.tight_layout()
#fig_lc_dpde_QS_32X.savefig("QS_dpde_32X_lc.pdf",dpi=300)

# %%
# Using 32X rowwise shuffled data
fig_lc_dpde_QS_32X_rwsh,axis_lc_dpde_QS_32X_rwsh = plt.subplots(1,1,figsize=(11,6))
colors_lc = ["cadetblue","goldenrod","darkgray","salmon"]
assess_ML(star_type="QS",mag_reg="dpde",x_data_types=["16X","16X_rwsh","32X","32X_rwsh"]).plot_learning_curves(3,axis_lc_dpde_QS_32X_rwsh,colors_lc)
fig_lc_dpde_QS_32X_rwsh.tight_layout()
#fig_lc_dpde_QS_32X_rwsh.savefig("QS_dpde_32X_rwsh_lc.pdf",dpi=300)

# %% [markdown]
# ### **B. Predicting energy on center $E_c$ values**

# %%
# Using 16X data
fig_lc_enrg_QS_16X,axis_lc_enrg_QS_16X = plt.subplots(1,1,figsize=(9,6))
colors_lc = ["cadetblue","goldenrod","darkgray","salmon"]
assess_ML(star_type="QS",mag_reg="enrg",x_data_types=["16X","16X_rwsh","32X","32X_rwsh"]).plot_learning_curves(0,axis_lc_enrg_QS_16X,colors_lc)

# %%
# Using 16X rowwise shuffled data
fig_lc_enrg_QS_16X_rwsh,axis_lc_enrg_QS_16X_rwsh = plt.subplots(1,1,figsize=(9,6))
colors_lc = ["cadetblue","goldenrod","darkgray","salmon"]
assess_ML(star_type="QS",mag_reg="enrg",x_data_types=["16X","16X_rwsh","32X","32X_rwsh"]).plot_learning_curves(1,axis_lc_enrg_QS_16X_rwsh,colors_lc)

# %%
# Using 32X data
fig_lc_enrg_QS_32X,axis_lc_enrg_QS_32X = plt.subplots(1,1,figsize=(9,6))
colors_lc = ["cadetblue","goldenrod","darkgray","salmon"]
assess_ML(star_type="QS",mag_reg="enrg",x_data_types=["16X","16X_rwsh","32X","32X_rwsh"]).plot_learning_curves(2,axis_lc_enrg_QS_32X,colors_lc)

# %%
# Using 32X rowwise shuffled data
fig_lc_enrg_QS_32X_rwsh,axis_lc_enrg_QS_32X_rwsh = plt.subplots(1,1,figsize=(9,6))
colors_lc = ["cadetblue","goldenrod","darkgray","salmon"]
assess_ML(star_type="QS",mag_reg="enrg",x_data_types=["16X","16X_rwsh","32X","32X_rwsh"]).plot_learning_curves(3,axis_lc_enrg_QS_32X_rwsh,colors_lc)

# %% [markdown]
# ### **D. Predicting center pressure at maximum mass $P_c(M_{max})$ values**

# %%
# Using 16X data
fig_lc_PcMmax_QS_16X,axis_lc_PcMmax_QS_16X = plt.subplots(1,1,figsize=(9,6))
colors_lc = ["cadetblue","goldenrod","darkgray","salmon"]
assess_ML(star_type="QS",mag_reg="PcMmax",x_data_types=["16X","16X_rwsh","32X","32X_rwsh"]).plot_learning_curves(0,axis_lc_PcMmax_QS_16X,colors_lc)

# %%
# Using 16X rowwise shuffled data
fig_lc_PcMmax_QS_16X_rwsh,axis_lc_PcMmax_QS_16X_rwsh = plt.subplots(1,1,figsize=(9,6))
colors_lc = ["cadetblue","goldenrod","darkgray","salmon"]
assess_ML(star_type="QS",mag_reg="PcMmax",x_data_types=["16X","16X_rwsh","32X","32X_rwsh"]).plot_learning_curves(1,axis_lc_PcMmax_QS_16X_rwsh,colors_lc)

# %%
# Using 32X data
fig_lc_PcMmax_QS_32X,axis_lc_PcMmax_QS_32X = plt.subplots(1,1,figsize=(9,6))
colors_lc = ["cadetblue","goldenrod","darkgray","salmon"]
assess_ML(star_type="QS",mag_reg="PcMmax",x_data_types=["16X","16X_rwsh","32X","32X_rwsh"]).plot_learning_curves(2,axis_lc_PcMmax_QS_32X,colors_lc)

# %%
# Using 32X rowwise shuffled data
fig_lc_PcMmax_QS_32X_rwsh,axis_lc_PcMmax_QS_32X_rwsh = plt.subplots(1,1,figsize=(9,6))
colors_lc = ["cadetblue","goldenrod","darkgray","salmon"]
assess_ML(star_type="QS",mag_reg="PcMmax",x_data_types=["16X","16X_rwsh","32X","32X_rwsh"]).plot_learning_curves(3,axis_lc_PcMmax_QS_32X_rwsh,colors_lc)
