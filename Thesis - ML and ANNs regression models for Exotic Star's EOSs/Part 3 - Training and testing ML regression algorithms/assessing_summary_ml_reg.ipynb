# %% [markdown]
# **MSc Computational Physics AUTh**<br>
# **Academic Year: 2024-2025**<br>
# **Master's Thesis**<br>
#
# **Thesis Title:**<br>
# # **"Reconstruction of the EoSs of Exotic Stars using ML and ANNs regression models"**
#
# **Implemented by: Ioannis Stergakis**<br>
# **AEM: 4439**<br>
#
# **Jupyter Notebook: JN5**<br>
# **Name: "assessing_summary_ml_reg.ipynb"**<br>
#
# **Description:**<br>
# **Assessing machine learning regression models**<br>
# **1. Summarizing and saving the results of metrics in .csv files**<br>
# **2. Printing and comparing their metrics**<br>
# **3. Making groups of bar plots to compare test vs overfitting results for 16 or 32 X data (row-wise shuffled)**<br>
#
#
# **Abbrevations:**<br>
# **1. NS -> Neutron Star**<br>
# **2. QS -> Quark Star**<br>
# **3. ML -> Machine Learning**

# %%
# Importing useful modules
from data_analysis_ES_ML import *
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # 1. Neutron Stars

# %% [markdown]
# ## **1.1 Summarizing and saving metric results in .csv files**

# %%
# Saving MSLE results
assess_ML(star_type="NS",mag_reg="enrg",x_data_types=["16X_rwsh","32X_rwsh"],EOS_type="lin").save_metric_results("msle") # results for energy density on center ε_c prediction
# Out:
# The MSLE results for "enrg" prediction have been summarized and saved on the linNS_enrg_msle_res.csv file !!!

# %%
# Saving MSE results
assess_ML(star_type="NS",mag_reg="enrg",x_data_types=["16X_rwsh","32X_rwsh"],EOS_type="lin").save_metric_results("mse") # results for energy density on center ε_c prediction
# Out:
# The MSE results for "enrg" prediction have been summarized and saved on the linNS_enrg_mse_res.csv file !!!

# %% [markdown]
# ## **1.2 Printing the metrics results in PrettyTable format**

# %%
# MSLE results
print(">Energy density on center ε_c prediction (MSLE results):")
assess_ML(star_type="NS",mag_reg="enrg",x_data_types=["16X_rwsh","32X_rwsh"],EOS_type="lin").print_metric_results("msle")
# MSE results
print("\n>Energy density on center ε_c prediction (MSE results):")
assess_ML(star_type="NS",mag_reg="enrg",x_data_types=["16X_rwsh","32X_rwsh"],EOS_type="lin").print_metric_results("mse")
# Out:
# >Energy density on center ε_c prediction (MSLE results):
# +------------------+-------------------------+-------------------------+
# |  models\X_type   |     16X_rwsh (ovf.)     |     32X_rwsh (ovf.)     |
# +------------------+-------------------------+-------------------------+
# |   DecisionTree   | 1.3471e-02 (5.6265e-03) | 1.6619e-02 (6.2758e-03) |
# |   RandomForest   | 7.8702e-03 (4.9644e-03) | 8.6574e-03 (5.0589e-03) |
# | GradientBoosting | 7.7523e-03 (6.4702e-03) | 7.8216e-03 (6.2263e-03) |
# |     XGBoost      | 6.2497e-03 (2.8894e-03) | 6.2869e-03 (2.1967e-03) |
# +------------------+-------------------------+-------------------------+
#
# >Energy density on center ε_c prediction (MSE results):
# +------------------+-------------------------+-------------------------+
# |  models\X_type   |     16X_rwsh (ovf.)     |     32X_rwsh (ovf.)     |
# +------------------+-------------------------+-------------------------+
# ...

# %% [markdown]
# ## **1.3 Making groups of bar plots**

# %%
# Initialzing the figure and axis
fig_gbar_enrg_NS,axis_gbar_enrg_NS = plt.subplots(2,1,figsize=(10,8))

# Defining the bar colors
bar_clrs_msle = ["cadetblue","goldenrod"]
bar_clrs_mse = ["mediumseagreen","salmon"]

# MSLE results
assess_ML(star_type="NS",mag_reg="enrg",x_data_types=["16X_rwsh","32X_rwsh"],EOS_type="lin").make_bar_plots("msle",axis_gbar_enrg_NS[0],bar_colors=bar_clrs_msle)
# MSE results
assess_ML(star_type="NS",mag_reg="enrg",x_data_types=["16X_rwsh","32X_rwsh"],EOS_type="lin").make_bar_plots("mse",axis_gbar_enrg_NS[1],bar_colors=bar_clrs_mse)

fig_gbar_enrg_NS.tight_layout()

# %% [markdown]
# # 2. Quark Stars

# %% [markdown]
# ## **2.1 Summarizing and saving metric results in .csv files**

# %%
# Saving MSLE results
assess_ML(star_type="QS",mag_reg="enrg",x_data_types=["16X_rwsh","32X_rwsh"]).save_metric_results("msle") # results for energy density on center ε_c prediction
# Out:
# The MSLE results for "enrg" prediction have been summarized and saved on the QS_enrg_msle_res.csv file !!!

# %%
# Saving MSE results
assess_ML(star_type="QS",mag_reg="enrg",x_data_types=["16X_rwsh","32X_rwsh"]).save_metric_results("mse") # results for energy density on center ε_c prediction
# Out:
# The MSE results for "enrg" prediction have been summarized and saved on the QS_enrg_mse_res.csv file !!!

# %% [markdown]
# ## **2.2 Printing the metrics results in PrettyTable format**

# %%
# MSLE results
print(">Energy density on center ε_c prediction (MSLE results):")
assess_ML(star_type="QS",mag_reg="enrg",x_data_types=["16X_rwsh","32X_rwsh"]).print_metric_results("msle")
# MSE results
print("\n>Energy density on center ε_c prediction (MSE results):")
assess_ML(star_type="QS",mag_reg="enrg",x_data_types=["16X_rwsh","32X_rwsh"]).print_metric_results("mse")
# Out:
# >Energy density on center ε_c prediction (MSLE results):
# +------------------+-------------------------+-------------------------+
# |  models\X_type   |     16X_rwsh (ovf.)     |     32X_rwsh (ovf.)     |
# +------------------+-------------------------+-------------------------+
# |   DecisionTree   | 6.4606e-03 (2.4405e-03) | 7.3603e-03 (3.2674e-03) |
# |   RandomForest   | 3.6985e-03 (2.2021e-03) | 3.6024e-03 (1.9554e-03) |
# | GradientBoosting | 4.2502e-03 (3.9046e-03) | 4.0957e-03 (3.7241e-03) |
# |     XGBoost      | 2.8823e-03 (2.0393e-03) | 2.4962e-03 (1.5754e-03) |
# +------------------+-------------------------+-------------------------+
#
# >Energy density on center ε_c prediction (MSE results):
# +------------------+-------------------------+-------------------------+
# |  models\X_type   |     16X_rwsh (ovf.)     |     32X_rwsh (ovf.)     |
# +------------------+-------------------------+-------------------------+
# ...

# %% [markdown]
# ## **2.3 Making groups of bar plots**

# %%
# Initialzing the figure and axis
fig_gbar_enrg_QS,axis_gbar_enrg_QS = plt.subplots(2,1,figsize=(10,8))

# Defining the bar colors
bar_clrs_mse = ["cadetblue","goldenrod"]
bar_clrs_msle = ["mediumseagreen","salmon"]

# MSLE results
assess_ML(star_type="QS",mag_reg="enrg",x_data_types=["16X_rwsh","32X_rwsh"]).make_bar_plots("msle",axis_gbar_enrg_QS[0],bar_colors=bar_clrs_msle)
# MSE results
assess_ML(star_type="QS",mag_reg="enrg",x_data_types=["16X_rwsh","32X_rwsh"]).make_bar_plots("mse",axis_gbar_enrg_QS[1],bar_colors=bar_clrs_mse)

fig_gbar_enrg_QS.tight_layout()
