# %% [markdown]
# **MSc Computational Physics AUTh**<br>
# **Academic Year: 2024-2025**<br>
# **Master's Thesis**<br>
#
# **Thesis Title:**<br>
# # **"Reconstruction of the EoSs of Exotic Stars using ML and ANNs regression models"**
#
# **Implemented by: Ioannis Stergakis**<br>
# **AEM: 4439**<br>
#
# **Jupyter Notebook: JN4d**<br>
# **Name: "testing_adaboost_regress.ipynb"**<br>
#
# **Description:**<br>
# **Training and testing the `AdaBoost Regressor` algorithm:**<br>
# **1. Performing grid search to determine the best hyperparameters**<br>
# **2. Performing cross validation to optimize the model for future foreign data**<br>
# **3. Assessing the accuracy of the best model using different scorers and metrics**
#
#
# **Abbrevations:**<br>
# **1. NS -> Neutron Star**<br>
# **2. QS -> Quark Star**<br>
# **3. ML -> Machine Learning**

# %%
# Importing useful modules
import joblib
from data_analysis_ES_ML import *

# %%
# Defining the grid of hyperparameters values for the 'AdaBoost' regressor
adaboost_grid = {
    'estimator__n_estimators': [50, 75, 100],
    'estimator__learning_rate': [0.01, 0.1, 0.5, 1.0],
    'estimator__loss': ['linear', 'square', 'exponential']
}

# %% [markdown]
# # 1. Neutron Stars

# %% [markdown]
# ## **1.1 Using 8 M-R points**

# %% [markdown]
# ### A. Predicting Slope $\frac{dP}{dE}=c^2_s$ Values

# %% [markdown]
# #### ->Using non-shuffled data

# %%
# Showing the datasets
# regression_ML("NS_reg_data_pp8mr8s100.csv","dPdE",0.25).show_datasets()

# %%
# Building a regression model
regression_ML("NS_reg_data_pp8mr8s100.csv",mag_reg="dPdE",test_ratio=0.25).train_test("adaboost",5,adaboost_grid,"msle",cores_par=18,filesave="NS_adaboost_grid_dpde_16X")
# Out:
# TRAINING AND ASSESSING A MACHINE LEARNING REGRESSION MODEL
#
#
# >Preliminaries
# ...
# >> DATA INFO AND SCALING:
# -------------------------------------------------------------------------------------------------------------------
# Y (response) data type: "dPdE"
# Number of Y columns:  8
# X (explanatory) data type: "Mass" and "Radius"
# Number of X columns:  16
# The scaling of the X (explanatory) data has been completed
# -------------------------------------------------------------------------------------------------------------------
# >> CROSS-VALIDATION SETTINGS:
# -------------------------------------------------------------------------------------------------------------------
# The KFold cross-validator has been initialized with 5 n_splits
# The cross-validation scorer has been initialized with the "Mean_Squared_Log_Error" as metric
# -------------------------------------------------------------------------------------------------------------------
# >> ESTIMATOR INFO:
# ...

# %% [markdown]
# #### ->Using rowwise-shuffled data

# %%
# Showing the datasets
# regression_ML("NS_reg_data_pp8mr8s100_rwshuffled.csv","dPdE",0.25).show_datasets()

# %%
# Building a regression model
regression_ML("NS_reg_data_pp8mr8s100_rwshuffled.csv",mag_reg="dPdE",test_ratio=0.25).train_test("adaboost",5,adaboost_grid,"msle",cores_par=18,filesave="NS_adaboost_grid_dpde_16X_rwsh")
# Out:
# TRAINING AND ASSESSING A MACHINE LEARNING REGRESSION MODEL
#
#
# >Preliminaries
# ...
# >> DATA INFO AND SCALING:
# -------------------------------------------------------------------------------------------------------------------
# Y (response) data type: "dPdE"
# Number of Y columns:  8
# X (explanatory) data type: "Mass" and "Radius"
# Number of X columns:  16
# The scaling of the X (explanatory) data has been completed
# -------------------------------------------------------------------------------------------------------------------
# >> CROSS-VALIDATION SETTINGS:
# -------------------------------------------------------------------------------------------------------------------
# The KFold cross-validator has been initialized with 5 n_splits
# The cross-validation scorer has been initialized with the "Mean_Squared_Log_Error" as metric
# -------------------------------------------------------------------------------------------------------------------
# >> ESTIMATOR INFO:
# ...

# %% [markdown]
# ### B. Predicting Energy on center $E_c$ Values

# %% [markdown]
# #### ->Using non-shuffled data

# %%
# Showing the datasets
# regression_ML("NS_reg_data_pp8mr8s100.csv","enrg",0.25).show_datasets()

# %%
# Building a regression model
regression_ML("NS_reg_data_pp8mr8s100.csv",mag_reg="enrg",test_ratio=0.25).train_test("adaboost",5,adaboost_grid,"msle",cores_par=18,filesave="NS_adaboost_grid_enrg_16X")
# Out:
# TRAINING AND ASSESSING A MACHINE LEARNING REGRESSION MODEL
#
#
# >Preliminaries
# ...
# >> DATA INFO AND SCALING:
# -------------------------------------------------------------------------------------------------------------------
# Y (response) data type: "enrg"
# Number of Y columns:  8
# X (explanatory) data type: "Mass" and "Radius"
# Number of X columns:  16
# The scaling of the X (explanatory) data has been completed
# -------------------------------------------------------------------------------------------------------------------
# >> CROSS-VALIDATION SETTINGS:
# -------------------------------------------------------------------------------------------------------------------
# The KFold cross-validator has been initialized with 5 n_splits
# The cross-validation scorer has been initialized with the "Mean_Squared_Log_Error" as metric
# -------------------------------------------------------------------------------------------------------------------
# >> ESTIMATOR INFO:
# ...

# %% [markdown]
# #### ->Using rowwise-shuffled data

# %%
# Showing the datasets
# regression_ML("NS_reg_data_pp8mr8s100_rwshuffled.csv","enrg",0.25).show_datasets()

# %%
# Building a regression model
regression_ML("NS_reg_data_pp8mr8s100_rwshuffled.csv",mag_reg="enrg",test_ratio=0.25).train_test("adaboost",5,adaboost_grid,"msle",cores_par=18,filesave="NS_adaboost_grid_enrg_16X_rwsh")
# Out:
# TRAINING AND ASSESSING A MACHINE LEARNING REGRESSION MODEL
#
#
# >Preliminaries
# ...
# >> DATA INFO AND SCALING:
# -------------------------------------------------------------------------------------------------------------------
# Y (response) data type: "enrg"
# Number of Y columns:  8
# X (explanatory) data type: "Mass" and "Radius"
# Number of X columns:  16
# The scaling of the X (explanatory) data has been completed
# -------------------------------------------------------------------------------------------------------------------
# >> CROSS-VALIDATION SETTINGS:
# -------------------------------------------------------------------------------------------------------------------
# The KFold cross-validator has been initialized with 5 n_splits
# The cross-validation scorer has been initialized with the "Mean_Squared_Log_Error" as metric
# -------------------------------------------------------------------------------------------------------------------
# >> ESTIMATOR INFO:
# ...

# %% [markdown]
# ### C. Predicting polytropic parameter $\Gamma$ Values

# %% [markdown]
# #### ->Using non-shuffled data

# %%
# Showing the datasets
# regression_ML("NS_reg_data_pp8mr8s100.csv","Gamma",0.25).show_datasets()

# %%
# Building a regression model
regression_ML("NS_reg_data_pp8mr8s100.csv",mag_reg="Gamma",test_ratio=0.25).train_test("adaboost",5,adaboost_grid,"msle",cores_par=18,filesave="NS_adaboost_grid_gamma_16X")
# Out:
# TRAINING AND ASSESSING A MACHINE LEARNING REGRESSION MODEL
#
#
# >Preliminaries
# ...
# >> DATA INFO AND SCALING:
# -------------------------------------------------------------------------------------------------------------------
# Y (response) data type: "Gamma"
# Number of Y columns:  4
# X (explanatory) data type: "Mass" and "Radius"
# Number of X columns:  16
# The scaling of the X (explanatory) data has been completed
# -------------------------------------------------------------------------------------------------------------------
# >> CROSS-VALIDATION SETTINGS:
# -------------------------------------------------------------------------------------------------------------------
# The KFold cross-validator has been initialized with 5 n_splits
# The cross-validation scorer has been initialized with the "Mean_Squared_Log_Error" as metric
# -------------------------------------------------------------------------------------------------------------------
# >> ESTIMATOR INFO:
# ...

# %% [markdown]
# #### ->Using rowwise-shuffled data

# %%
# Showing the datasets
# regression_ML("NS_reg_data_pp8mr8s100_rwshuffled.csv","Gamma",0.25).show_datasets()

# %%
# Building a regression model
regression_ML("NS_reg_data_pp8mr8s100_rwshuffled.csv",mag_reg="Gamma",test_ratio=0.25).train_test("adaboost",5,adaboost_grid,"msle",cores_par=18,filesave="NS_adaboost_grid_gamma_16X_rwsh")
# Out:
# TRAINING AND ASSESSING A MACHINE LEARNING REGRESSION MODEL
#
#
# >Preliminaries
# ...
# >> DATA INFO AND SCALING:
# -------------------------------------------------------------------------------------------------------------------
# Y (response) data type: "Gamma"
# Number of Y columns:  4
# X (explanatory) data type: "Mass" and "Radius"
# Number of X columns:  16
# The scaling of the X (explanatory) data has been completed
# -------------------------------------------------------------------------------------------------------------------
# >> CROSS-VALIDATION SETTINGS:
# -------------------------------------------------------------------------------------------------------------------
# The KFold cross-validator has been initialized with 5 n_splits
# The cross-validation scorer has been initialized with the "Mean_Squared_Log_Error" as metric
# -------------------------------------------------------------------------------------------------------------------
# >> ESTIMATOR INFO:
# ...

# %% [markdown]
# ### D. Predicting center pressure on maximum mass $P_c(M_{max})$ Values

# %% [markdown]
# #### ->Using non-shuffled data

# %%
# Showing the datasets
# regression_ML("NS_reg_data_pp8mr8s100.csv","PcMmax",0.25).show_datasets()

# %%
# Building a regression model
regression_ML("NS_reg_data_pp8mr8s100.csv",mag_reg="PcMmax",test_ratio=0.25).train_test("adaboost",5,adaboost_grid,"msle",cores_par=18,filesave="NS_adaboost_grid_PcMmax_16X")
# Out:
# TRAINING AND ASSESSING A MACHINE LEARNING REGRESSION MODEL
#
#
# >Preliminaries
# ...
# >> DATA INFO AND SCALING:
# -------------------------------------------------------------------------------------------------------------------
# Y (response) data type: "PcMmax"
# Number of Y columns:  1
# X (explanatory) data type: "Mass" and "Radius"
# Number of X columns:  16
# The scaling of the X (explanatory) data has been completed
# -------------------------------------------------------------------------------------------------------------------
# >> CROSS-VALIDATION SETTINGS:
# -------------------------------------------------------------------------------------------------------------------
# The KFold cross-validator has been initialized with 5 n_splits
# The cross-validation scorer has been initialized with the "Mean_Squared_Log_Error" as metric
# -------------------------------------------------------------------------------------------------------------------
# >> ESTIMATOR INFO:
# ...

# %% [markdown]
# #### ->Using rowwise-shuffled data

# %%
# Showing the datasets
# regression_ML("NS_reg_data_pp8mr8s100_rwshuffled.csv","PcMmax",0.25).show_datasets()

# %%
# Building a regression model
regression_ML("NS_reg_data_pp8mr8s100_rwshuffled.csv",mag_reg="PcMmax",test_ratio=0.25).train_test("adaboost",5,adaboost_grid,"msle",cores_par=18,filesave="NS_adaboost_grid_PcMmax_16X_rwsh")
# Out:
# TRAINING AND ASSESSING A MACHINE LEARNING REGRESSION MODEL
#
#
# >Preliminaries
# ...
# >> DATA INFO AND SCALING:
# -------------------------------------------------------------------------------------------------------------------
# Y (response) data type: "PcMmax"
# Number of Y columns:  1
# X (explanatory) data type: "Mass" and "Radius"
# Number of X columns:  16
# The scaling of the X (explanatory) data has been completed
# -------------------------------------------------------------------------------------------------------------------
# >> CROSS-VALIDATION SETTINGS:
# -------------------------------------------------------------------------------------------------------------------
# The KFold cross-validator has been initialized with 5 n_splits
# The cross-validation scorer has been initialized with the "Mean_Squared_Log_Error" as metric
# -------------------------------------------------------------------------------------------------------------------
# >> ESTIMATOR INFO:
# ...

# %% [markdown]
# ## **1.2 Using 16 M-R points**

# %% [markdown]
# ### A. Predicting Slope $\frac{dP}{dE}=c^2_s$ Values

# %% [markdown]
# #### ->Using non-shuffled data

# %%
# Showing the datasets
# regression_ML("NS_reg_data_pp8mr16s100.csv","dPdE",0.25).show_datasets()

# %%
# Building a regression model
regression_ML("NS_reg_data_pp8mr16s100.csv",mag_reg="dPdE",test_ratio=0.25).train_test("adaboost",5,adaboost_grid,"msle",cores_par=18,filesave="NS_adaboost_grid_dpde_32X")
# Out:
# TRAINING AND ASSESSING A MACHINE LEARNING REGRESSION MODEL
#
#
# >Preliminaries
# ...
# >> DATA INFO AND SCALING:
# -------------------------------------------------------------------------------------------------------------------
# Y (response) data type: "dPdE"
# Number of Y columns:  8
# X (explanatory) data type: "Mass" and "Radius"
# Number of X columns:  32
# The scaling of the X (explanatory) data has been completed
# -------------------------------------------------------------------------------------------------------------------
# >> CROSS-VALIDATION SETTINGS:
# -------------------------------------------------------------------------------------------------------------------
# The KFold cross-validator has been initialized with 5 n_splits
# The cross-validation scorer has been initialized with the "Mean_Squared_Log_Error" as metric
# -------------------------------------------------------------------------------------------------------------------
# >> ESTIMATOR INFO:
# ...

# %% [markdown]
# #### ->Using rowwise-shuffled data

# %%
# Showing the datasets
# regression_ML("NS_reg_data_pp8mr16s100_rwshuffled.csv","dPdE",0.25).show_datasets()

# %%
# Building a regression model
regression_ML("NS_reg_data_pp8mr16s100_rwshuffled.csv",mag_reg="dPdE",test_ratio=0.25).train_test("adaboost",5,adaboost_grid,"msle",cores_par=18,filesave="NS_adaboost_grid_dpde_32X_rwsh")
# Out:
# TRAINING AND ASSESSING A MACHINE LEARNING REGRESSION MODEL
#
#
# >Preliminaries
# ...
# >> DATA INFO AND SCALING:
# -------------------------------------------------------------------------------------------------------------------
# Y (response) data type: "dPdE"
# Number of Y columns:  8
# X (explanatory) data type: "Mass" and "Radius"
# Number of X columns:  32
# The scaling of the X (explanatory) data has been completed
# -------------------------------------------------------------------------------------------------------------------
# >> CROSS-VALIDATION SETTINGS:
# -------------------------------------------------------------------------------------------------------------------
# The KFold cross-validator has been initialized with 5 n_splits
# The cross-validation scorer has been initialized with the "Mean_Squared_Log_Error" as metric
# -------------------------------------------------------------------------------------------------------------------
# >> ESTIMATOR INFO:
# ...

# %% [markdown]
# ### B. Predicting Energy on center $E_c$ Values

# %% [markdown]
# #### ->Using non-shuffled data

# %%
# Showing the datasets
# regression_ML("NS_reg_data_pp8mr16s100.csv","enrg",0.25).show_datasets()

# %%
# Building a regression model
regression_ML("NS_reg_data_pp8mr16s100.csv",mag_reg="enrg",test_ratio=0.25).train_test("adaboost",5,adaboost_grid,"msle",cores_par=18,filesave="NS_adaboost_grid_enrg_32X")
# Out:
# TRAINING AND ASSESSING A MACHINE LEARNING REGRESSION MODEL
#
#
# >Preliminaries
# ...
# >> DATA INFO AND SCALING:
# -------------------------------------------------------------------------------------------------------------------
# Y (response) data type: "enrg"
# Number of Y columns:  8
# X (explanatory) data type: "Mass" and "Radius"
# Number of X columns:  32
# The scaling of the X (explanatory) data has been completed
# -------------------------------------------------------------------------------------------------------------------
# >> CROSS-VALIDATION SETTINGS:
# -------------------------------------------------------------------------------------------------------------------
# The KFold cross-validator has been initialized with 5 n_splits
# The cross-validation scorer has been initialized with the "Mean_Squared_Log_Error" as metric
# -------------------------------------------------------------------------------------------------------------------
# >> ESTIMATOR INFO:
# ...

# %% [markdown]
# #### ->Using rowwise-shuffled data

# %%
# Showing the datasets
# regression_ML("NS_reg_data_pp8mr16s100_rwshuffled.csv","enrg",0.25).show_datasets()

# %%
# Building a regression model
regression_ML("NS_reg_data_pp8mr16s100_rwshuffled.csv",mag_reg="enrg",test_ratio=0.25).train_test("adaboost",5,adaboost_grid,"msle",cores_par=18,filesave="NS_adaboost_grid_enrg_32X_rwsh")
# Out:
# TRAINING AND ASSESSING A MACHINE LEARNING REGRESSION MODEL
#
#
# >Preliminaries
# ...
# >> DATA INFO AND SCALING:
# -------------------------------------------------------------------------------------------------------------------
# Y (response) data type: "enrg"
# Number of Y columns:  8
# X (explanatory) data type: "Mass" and "Radius"
# Number of X columns:  32
# The scaling of the X (explanatory) data has been completed
# -------------------------------------------------------------------------------------------------------------------
# >> CROSS-VALIDATION SETTINGS:
# -------------------------------------------------------------------------------------------------------------------
# The KFold cross-validator has been initialized with 5 n_splits
# The cross-validation scorer has been initialized with the "Mean_Squared_Log_Error" as metric
# -------------------------------------------------------------------------------------------------------------------
# >> ESTIMATOR INFO:
# ...

# %% [markdown]
# ### C. Predicting polytropic parameter $\Gamma$ Values

# %% [markdown]
# #### ->Using non-shuffled data

# %%
# Showing the datasets
# regression_ML("NS_reg_data_pp8mr16s100.csv","Gamma",0.25).show_datasets()

# %%
# Building a regression model
regression_ML("NS_reg_data_pp8mr16s100.csv",mag_reg="Gamma",test_ratio=0.25).train_test("adaboost",5,adaboost_grid,"msle",cores_par=18,filesave="NS_adaboost_grid_gamma_32X")
# Out:
# TRAINING AND ASSESSING A MACHINE LEARNING REGRESSION MODEL
#
#
# >Preliminaries
# ...
# >> DATA INFO AND SCALING:
# -------------------------------------------------------------------------------------------------------------------
# Y (response) data type: "Gamma"
# Number of Y columns:  4
# X (explanatory) data type: "Mass" and "Radius"
# Number of X columns:  32
# The scaling of the X (explanatory) data has been completed
# -------------------------------------------------------------------------------------------------------------------
# >> CROSS-VALIDATION SETTINGS:
# -------------------------------------------------------------------------------------------------------------------
# The KFold cross-validator has been initialized with 5 n_splits
# The cross-validation scorer has been initialized with the "Mean_Squared_Log_Error" as metric
# -------------------------------------------------------------------------------------------------------------------
# >> ESTIMATOR INFO:
# ...

# %% [markdown]
# #### ->Using rowwise-shuffled data

# %%
# Showing the datasets
# regression_ML("NS_reg_data_pp8mr16s100_rwshuffled.csv","Gamma",0.25).show_datasets()

# %%
# Building a regression model
regression_ML("NS_reg_data_pp8mr16s100_rwshuffled.csv",mag_reg="Gamma",test_ratio=0.25).train_test("adaboost",5,adaboost_grid,"msle",cores_par=18,filesave="NS_adaboost_grid_gamma_32X_rwsh")
# Out:
# TRAINING AND ASSESSING A MACHINE LEARNING REGRESSION MODEL
#
#
# >Preliminaries
# ...
# >> DATA INFO AND SCALING:
# -------------------------------------------------------------------------------------------------------------------
# Y (response) data type: "Gamma"
# Number of Y columns:  4
# X (explanatory) data type: "Mass" and "Radius"
# Number of X columns:  32
# The scaling of the X (explanatory) data has been completed
# -------------------------------------------------------------------------------------------------------------------
# >> CROSS-VALIDATION SETTINGS:
# -------------------------------------------------------------------------------------------------------------------
# The KFold cross-validator has been initialized with 5 n_splits
# The cross-validation scorer has been initialized with the "Mean_Squared_Log_Error" as metric
# -------------------------------------------------------------------------------------------------------------------
# >> ESTIMATOR INFO:
# ...

# %% [markdown]
# ### D. Predicting center pressure on maximum mass $P_c(M_{max})$ Values

# %% [markdown]
# #### ->Using non-shuffled data

# %%
# Showing the datasets
# regression_ML("NS_reg_data_pp8mr16s100.csv","PcMmax",0.25).show_datasets()

# %%
# Building a regression model
regression_ML("NS_reg_data_pp8mr16s100.csv",mag_reg="PcMmax",test_ratio=0.25).train_test("adaboost",5,adaboost_grid,"msle",cores_par=18,filesave="NS_adaboost_grid_PcMmax_32X")
# Out:
# TRAINING AND ASSESSING A MACHINE LEARNING REGRESSION MODEL
#
#
# >Preliminaries
# ...
# >> DATA INFO AND SCALING:
# -------------------------------------------------------------------------------------------------------------------
# Y (response) data type: "PcMmax"
# Number of Y columns:  1
# X (explanatory) data type: "Mass" and "Radius"
# Number of X columns:  32
# The scaling of the X (explanatory) data has been completed
# -------------------------------------------------------------------------------------------------------------------
# >> CROSS-VALIDATION SETTINGS:
# -------------------------------------------------------------------------------------------------------------------
# The KFold cross-validator has been initialized with 5 n_splits
# The cross-validation scorer has been initialized with the "Mean_Squared_Log_Error" as metric
# -------------------------------------------------------------------------------------------------------------------
# >> ESTIMATOR INFO:
# ...

# %% [markdown]
# #### ->Using rowwise-shuffled data

# %%
# Showing the datasets
# regression_ML("NS_reg_data_pp8mr16s100_rwshuffled.csv","PcMmax",0.25).show_datasets()

# %%
# Building a regression model
regression_ML("NS_reg_data_pp8mr16s100_rwshuffled.csv",mag_reg="PcMmax",test_ratio=0.25).train_test("adaboost",5,adaboost_grid,"msle",cores_par=18,filesave="NS_adaboost_grid_PcMmax_32X_rwsh")
# Out:
# TRAINING AND ASSESSING A MACHINE LEARNING REGRESSION MODEL
#
#
# >Preliminaries
# ...
# >> DATA INFO AND SCALING:
# -------------------------------------------------------------------------------------------------------------------
# Y (response) data type: "PcMmax"
# Number of Y columns:  1
# X (explanatory) data type: "Mass" and "Radius"
# Number of X columns:  32
# The scaling of the X (explanatory) data has been completed
# -------------------------------------------------------------------------------------------------------------------
# >> CROSS-VALIDATION SETTINGS:
# -------------------------------------------------------------------------------------------------------------------
# The KFold cross-validator has been initialized with 5 n_splits
# The cross-validation scorer has been initialized with the "Mean_Squared_Log_Error" as metric
# -------------------------------------------------------------------------------------------------------------------
# >> ESTIMATOR INFO:
# ...

# %% [markdown]
# # 2. Quark Stars

# %% [markdown]
# ## **2.1 Using 8 M-R points**

# %% [markdown]
# ### A. Predicting Slope $\frac{dP}{dE}=c^2_s$ Values

# %% [markdown]
# #### ->Using non-shuffled data

# %%
# Showing the datasets
# regression_ML("QS_reg_data_pp8mr8s100.csv","dPdE",0.25).show_datasets()

# %%
# Building a regression model
regression_ML("QS_reg_data_pp8mr8s100.csv",mag_reg="dPdE",test_ratio=0.25).train_test("adaboost",5,adaboost_grid,"msle",cores_par=18,filesave="QS_adaboost_grid_dpde_16X")
# Out:
# TRAINING AND ASSESSING A MACHINE LEARNING REGRESSION MODEL
#
#
# >Preliminaries
# ...
# >> DATA INFO AND SCALING:
# -------------------------------------------------------------------------------------------------------------------
# Y (response) data type: "dPdE"
# Number of Y columns:  8
# X (explanatory) data type: "Mass" and "Radius"
# Number of X columns:  16
# The scaling of the X (explanatory) data has been completed
# -------------------------------------------------------------------------------------------------------------------
# >> CROSS-VALIDATION SETTINGS:
# -------------------------------------------------------------------------------------------------------------------
# The KFold cross-validator has been initialized with 5 n_splits
# The cross-validation scorer has been initialized with the "Mean_Squared_Log_Error" as metric
# -------------------------------------------------------------------------------------------------------------------
# >> ESTIMATOR INFO:
# ...

# %% [markdown]
# #### ->Using rowwise-shuffled data

# %%
# Showing the datasets
# regression_ML("QS_reg_data_pp8mr8s100_rwshuffled.csv","dPdE",0.25).show_datasets()

# %%
# Building a regression model
regression_ML("QS_reg_data_pp8mr8s100_rwshuffled.csv",mag_reg="dPdE",test_ratio=0.25).train_test("adaboost",5,adaboost_grid,"msle",cores_par=18,filesave="QS_adaboost_grid_dpde_16X_rwsh")
# Out:
# TRAINING AND ASSESSING A MACHINE LEARNING REGRESSION MODEL
#
#
# >Preliminaries
# ...
# >> DATA INFO AND SCALING:
# -------------------------------------------------------------------------------------------------------------------
# Y (response) data type: "dPdE"
# Number of Y columns:  8
# X (explanatory) data type: "Mass" and "Radius"
# Number of X columns:  16
# The scaling of the X (explanatory) data has been completed
# -------------------------------------------------------------------------------------------------------------------
# >> CROSS-VALIDATION SETTINGS:
# -------------------------------------------------------------------------------------------------------------------
# The KFold cross-validator has been initialized with 5 n_splits
# The cross-validation scorer has been initialized with the "Mean_Squared_Log_Error" as metric
# -------------------------------------------------------------------------------------------------------------------
# >> ESTIMATOR INFO:
# ...

# %% [markdown]
# ### B. Predicting Energy on center $E_c$ Values

# %% [markdown]
# #### ->Using non-shuffled data

# %%
# Showing the datasets
# regression_ML("QS_reg_data_pp8mr8s100.csv","enrg",0.25).show_datasets()

# %%
# Building a regression model
regression_ML("QS_reg_data_pp8mr8s100.csv",mag_reg="enrg",test_ratio=0.25).train_test("adaboost",5,adaboost_grid,"msle",cores_par=18,filesave="QS_adaboost_grid_enrg_16X")
# Out:
# TRAINING AND ASSESSING A MACHINE LEARNING REGRESSION MODEL
#
#
# >Preliminaries
# ...
# >> DATA INFO AND SCALING:
# -------------------------------------------------------------------------------------------------------------------
# Y (response) data type: "enrg"
# Number of Y columns:  8
# X (explanatory) data type: "Mass" and "Radius"
# Number of X columns:  16
# The scaling of the X (explanatory) data has been completed
# -------------------------------------------------------------------------------------------------------------------
# >> CROSS-VALIDATION SETTINGS:
# -------------------------------------------------------------------------------------------------------------------
# The KFold cross-validator has been initialized with 5 n_splits
# The cross-validation scorer has been initialized with the "Mean_Squared_Log_Error" as metric
# -------------------------------------------------------------------------------------------------------------------
# >> ESTIMATOR INFO:
# ...

# %% [markdown]
# #### ->Using rowwise-shuffled data

# %%
# Showing the datasets
# regression_ML("QS_reg_data_pp8mr8s100_rwshuffled.csv","enrg",0.25).show_datasets()

# %%
# Building a regression model
regression_ML("QS_reg_data_pp8mr8s100_rwshuffled.csv",mag_reg="enrg",test_ratio=0.25).train_test("adaboost",5,adaboost_grid,"msle",cores_par=18,filesave="QS_adaboost_grid_enrg_16X_rwsh")
# Out:
# TRAINING AND ASSESSING A MACHINE LEARNING REGRESSION MODEL
#
#
# >Preliminaries
# ...
# >> DATA INFO AND SCALING:
# -------------------------------------------------------------------------------------------------------------------
# Y (response) data type: "enrg"
# Number of Y columns:  8
# X (explanatory) data type: "Mass" and "Radius"
# Number of X columns:  16
# The scaling of the X (explanatory) data has been completed
# -------------------------------------------------------------------------------------------------------------------
# >> CROSS-VALIDATION SETTINGS:
# -------------------------------------------------------------------------------------------------------------------
# The KFold cross-validator has been initialized with 5 n_splits
# The cross-validation scorer has been initialized with the "Mean_Squared_Log_Error" as metric
# -------------------------------------------------------------------------------------------------------------------
# >> ESTIMATOR INFO:
# ...

# %% [markdown]
# ### C. Predicting center pressure on maximum mass $P_c(M_{max})$ Values

# %% [markdown]
# #### ->Using non-shuffled data

# %%
# Showing the datasets
# regression_ML("QS_reg_data_pp8mr8s100.csv","PcMmax",0.25).show_datasets()

# %%
# Building a regression model
regression_ML("QS_reg_data_pp8mr8s100.csv",mag_reg="PcMmax",test_ratio=0.25).train_test("adaboost",5,adaboost_grid,"msle",cores_par=18,filesave="QS_adaboost_grid_PcMmax_16X")
# Out:
# TRAINING AND ASSESSING A MACHINE LEARNING REGRESSION MODEL
#
#
# >Preliminaries
# ...
# >> DATA INFO AND SCALING:
# -------------------------------------------------------------------------------------------------------------------
# Y (response) data type: "PcMmax"
# Number of Y columns:  1
# X (explanatory) data type: "Mass" and "Radius"
# Number of X columns:  16
# The scaling of the X (explanatory) data has been completed
# -------------------------------------------------------------------------------------------------------------------
# >> CROSS-VALIDATION SETTINGS:
# -------------------------------------------------------------------------------------------------------------------
# The KFold cross-validator has been initialized with 5 n_splits
# The cross-validation scorer has been initialized with the "Mean_Squared_Log_Error" as metric
# -------------------------------------------------------------------------------------------------------------------
# >> ESTIMATOR INFO:
# ...

# %% [markdown]
# #### ->Using rowwise-shuffled data

# %%
# Showing the datasets
# regression_ML("QS_reg_data_pp8mr8s100_rwshuffled.csv","PcMmax",0.25).show_datasets()

# %%
# Building a regression model
regression_ML("QS_reg_data_pp8mr8s100_rwshuffled.csv",mag_reg="PcMmax",test_ratio=0.25).train_test("adaboost",5,adaboost_grid,"msle",cores_par=18,filesave="QS_adaboost_grid_PcMmax_16X_rwsh")
# Out:
# TRAINING AND ASSESSING A MACHINE LEARNING REGRESSION MODEL
#
#
# >Preliminaries
# ...
# >> DATA INFO AND SCALING:
# -------------------------------------------------------------------------------------------------------------------
# Y (response) data type: "PcMmax"
# Number of Y columns:  1
# X (explanatory) data type: "Mass" and "Radius"
# Number of X columns:  16
# The scaling of the X (explanatory) data has been completed
# -------------------------------------------------------------------------------------------------------------------
# >> CROSS-VALIDATION SETTINGS:
# -------------------------------------------------------------------------------------------------------------------
# The KFold cross-validator has been initialized with 5 n_splits
# The cross-validation scorer has been initialized with the "Mean_Squared_Log_Error" as metric
# -------------------------------------------------------------------------------------------------------------------
# >> ESTIMATOR INFO:
# ...

# %% [markdown]
# ## **2.2 Using 16 M-R points**

# %% [markdown]
# ### A. Predicting Slope $\frac{dP}{dE}=c^2_s$ Values

# %% [markdown]
# #### ->Using non-shuffled data

# %%
# Showing the datasets
# regression_ML("QS_reg_data_pp8mr16s100.csv","dPdE",0.25).show_datasets()

# %%
# Building a regression model
regression_ML("QS_reg_data_pp8mr16s100.csv",mag_reg="dPdE",test_ratio=0.25).train_test("adaboost",5,adaboost_grid,"msle",cores_par=18,filesave="QS_adaboost_grid_dpde_32X")
# Out:
# TRAINING AND ASSESSING A MACHINE LEARNING REGRESSION MODEL
#
#
# >Preliminaries
# ...
# >> DATA INFO AND SCALING:
# -------------------------------------------------------------------------------------------------------------------
# Y (response) data type: "dPdE"
# Number of Y columns:  8
# X (explanatory) data type: "Mass" and "Radius"
# Number of X columns:  32
# The scaling of the X (explanatory) data has been completed
# -------------------------------------------------------------------------------------------------------------------
# >> CROSS-VALIDATION SETTINGS:
# -------------------------------------------------------------------------------------------------------------------
# The KFold cross-validator has been initialized with 5 n_splits
# The cross-validation scorer has been initialized with the "Mean_Squared_Log_Error" as metric
# -------------------------------------------------------------------------------------------------------------------
# >> ESTIMATOR INFO:
# ...

# %% [markdown]
# #### ->Using rowwise-shuffled data

# %%
# Showing the datasets
# regression_ML("QS_reg_data_pp8mr16s100_rwshuffled.csv","dPdE",0.25).show_datasets()

# %%
# Building a regression model
regression_ML("QS_reg_data_pp8mr16s100_rwshuffled.csv",mag_reg="dPdE",test_ratio=0.25).train_test("adaboost",5,adaboost_grid,"msle",cores_par=18,filesave="QS_adaboost_grid_dpde_32X_rwsh")
# Out:
# TRAINING AND ASSESSING A MACHINE LEARNING REGRESSION MODEL
#
#
# >Preliminaries
# ...
# >> DATA INFO AND SCALING:
# -------------------------------------------------------------------------------------------------------------------
# Y (response) data type: "dPdE"
# Number of Y columns:  8
# X (explanatory) data type: "Mass" and "Radius"
# Number of X columns:  32
# The scaling of the X (explanatory) data has been completed
# -------------------------------------------------------------------------------------------------------------------
# >> CROSS-VALIDATION SETTINGS:
# -------------------------------------------------------------------------------------------------------------------
# The KFold cross-validator has been initialized with 5 n_splits
# The cross-validation scorer has been initialized with the "Mean_Squared_Log_Error" as metric
# -------------------------------------------------------------------------------------------------------------------
# >> ESTIMATOR INFO:
# ...

# %% [markdown]
# ### B. Predicting Energy on center $E_c$ Values

# %% [markdown]
# #### ->Using non-shuffled data

# %%
# Showing the datasets
# regression_ML("QS_reg_data_pp8mr16s100.csv","enrg",0.25).show_datasets()

# %%
# Building a regression model
regression_ML("QS_reg_data_pp8mr16s100.csv",mag_reg="enrg",test_ratio=0.25).train_test("adaboost",5,adaboost_grid,"msle",cores_par=18,filesave="QS_adaboost_grid_enrg_32X")
# Out:
# TRAINING AND ASSESSING A MACHINE LEARNING REGRESSION MODEL
#
#
# >Preliminaries
# ...
# >> DATA INFO AND SCALING:
# -------------------------------------------------------------------------------------------------------------------
# Y (response) data type: "enrg"
# Number of Y columns:  8
# X (explanatory) data type: "Mass" and "Radius"
# Number of X columns:  32
# The scaling of the X (explanatory) data has been completed
# -------------------------------------------------------------------------------------------------------------------
# >> CROSS-VALIDATION SETTINGS:
# -------------------------------------------------------------------------------------------------------------------
# The KFold cross-validator has been initialized with 5 n_splits
# The cross-validation scorer has been initialized with the "Mean_Squared_Log_Error" as metric
# -------------------------------------------------------------------------------------------------------------------
# >> ESTIMATOR INFO:
# ...

# %% [markdown]
# #### ->Using rowwise-shuffled data

# %%
# Showing the datasets
# regression_ML("QS_reg_data_pp8mr16s100_rwshuffled.csv","enrg",0.25).show_datasets()

# %%
# Building a regression model
regression_ML("QS_reg_data_pp8mr16s100_rwshuffled.csv",mag_reg="enrg",test_ratio=0.25).train_test("adaboost",5,adaboost_grid,"msle",cores_par=18,filesave="QS_adaboost_grid_enrg_32X_rwsh")
# Out:
# TRAINING AND ASSESSING A MACHINE LEARNING REGRESSION MODEL
#
#
# >Preliminaries
# ...
# >> DATA INFO AND SCALING:
# -------------------------------------------------------------------------------------------------------------------
# Y (response) data type: "enrg"
# Number of Y columns:  8
# X (explanatory) data type: "Mass" and "Radius"
# Number of X columns:  32
# The scaling of the X (explanatory) data has been completed
# -------------------------------------------------------------------------------------------------------------------
# >> CROSS-VALIDATION SETTINGS:
# -------------------------------------------------------------------------------------------------------------------
# The KFold cross-validator has been initialized with 5 n_splits
# The cross-validation scorer has been initialized with the "Mean_Squared_Log_Error" as metric
# -------------------------------------------------------------------------------------------------------------------
# >> ESTIMATOR INFO:
# ...

# %% [markdown]
# ### C. Predicting center pressure on maximum mass $P_c(M_{max})$ Values

# %% [markdown]
# #### ->Using non-shuffled data

# %%
# Showing the datasets
# regression_ML("QS_reg_data_pp8mr16s100.csv","PcMmax",0.25).show_datasets()

# %%
# Building a regression model
regression_ML("QS_reg_data_pp8mr16s100.csv",mag_reg="PcMmax",test_ratio=0.25).train_test("adaboost",5,adaboost_grid,"msle",cores_par=18,filesave="QS_adaboost_grid_PcMmax_32X")
# Out:
# TRAINING AND ASSESSING A MACHINE LEARNING REGRESSION MODEL
#
#
# >Preliminaries
# ...
# >> DATA INFO AND SCALING:
# -------------------------------------------------------------------------------------------------------------------
# Y (response) data type: "PcMmax"
# Number of Y columns:  1
# X (explanatory) data type: "Mass" and "Radius"
# Number of X columns:  32
# The scaling of the X (explanatory) data has been completed
# -------------------------------------------------------------------------------------------------------------------
# >> CROSS-VALIDATION SETTINGS:
# -------------------------------------------------------------------------------------------------------------------
# The KFold cross-validator has been initialized with 5 n_splits
# The cross-validation scorer has been initialized with the "Mean_Squared_Log_Error" as metric
# -------------------------------------------------------------------------------------------------------------------
# >> ESTIMATOR INFO:
# ...

# %% [markdown]
# #### ->Using rowwise-shuffled data

# %%
# Showing the datasets
# regression_ML("QS_reg_data_pp8mr16s100_rwshuffled.csv","PcMmax",0.25).show_datasets()

# %%
# Building a regression model
regression_ML("QS_reg_data_pp8mr16s100_rwshuffled.csv",mag_reg="PcMmax",test_ratio=0.25).train_test("adaboost",5,adaboost_grid,"msle",cores_par=18,filesave="QS_adaboost_grid_PcMmax_32X_rwsh")
# Out:
# TRAINING AND ASSESSING A MACHINE LEARNING REGRESSION MODEL
#
#
# >Preliminaries
# ...
# >> DATA INFO AND SCALING:
# -------------------------------------------------------------------------------------------------------------------
# Y (response) data type: "PcMmax"
# Number of Y columns:  1
# X (explanatory) data type: "Mass" and "Radius"
# Number of X columns:  32
# The scaling of the X (explanatory) data has been completed
# -------------------------------------------------------------------------------------------------------------------
# >> CROSS-VALIDATION SETTINGS:
# -------------------------------------------------------------------------------------------------------------------
# The KFold cross-validator has been initialized with 5 n_splits
# The cross-validation scorer has been initialized with the "Mean_Squared_Log_Error" as metric
# -------------------------------------------------------------------------------------------------------------------
# >> ESTIMATOR INFO:
# ...
